# %% [markdown]
# # CirnecoDell'Etna

# %%
import pegtree as pg
from pegtree.colab import pegtree

# %%
# %%pegtree cirneco.pegtree
# 1+2
# Out:
# [#Source [#Expression [#Infix left: [#Int '1']name: [#Name '+']right: [#Int '2']]]]

# %%
# %%pegtree cirneco.pegtree
# print('hello world')
# print('hello',1)
# Out:
# [#Source [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString "'hello world'"]]]][#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString "'hello'"][#Int '1']]]]]

# %%
# %%pegtree cirneco.pegtree
# x = 1
# y = 2
# print(x+y)
# Out:
# [#Source [#VarDecl name: [#Name 'x']expr: [#Int '1']][#VarDecl name: [#Name 'y']expr: [#Int '2']][#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#Infix left: [#Name 'x']name: [#Name '+']right: [#Name 'y']]]]]]
