# %% [markdown]
# # CirnecoDell'Etna

# %%
import pegtree as pg
from pegtree.colab import pegtree

# %%
# %%pegtree cirneco.pegtree
# print('hello world')
# print('hello')
# Out:
# [#Source [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString "'hello world'"]]]][#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString "'hello'"]]]]]
