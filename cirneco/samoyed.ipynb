# %% [markdown]
# # Samoyed

# %%
import samoyed
# Out:
# Programming AI is supported

# %%
# %%samoyed
#
# a=1
# print(a+1)
# Out:
# 2

# %%
# %%samoyed --tree --code
# a = 1
# もしa+1が偶数のとき:
#     print(a,a+1)
# Out:
#   a = 1
#   if (a+1) % 2 == 0 :#もし<A>が偶数のとき
#     print(a,a + 1)
# 1 2
