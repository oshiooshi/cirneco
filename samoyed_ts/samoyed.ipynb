# %% [markdown]
# # CirnecoDell'Etna

# %%
import pegtree as pg
from pegtree.colab import pegtree

# %% [markdown]
# ?が付いているとあってもなくても良い
# / で囲ってあるとどっちか？？？
#
# きっちり書かなくても動作するように、?をつけておく
#
#
#
# 同じtreeになるように文法定義しています
#
# 何にもマッチしないとsyntaxこれを秋信さんにお渡ししてモデル作成

# %%
# %%pegtree samoyed.pegtree
# 1を返す
# return 1
# Out:
# [#Source [#Return expr: [#Int '1']][#Return expr: [#Int '1']]]

# %%
# %%pegtree samoyed.pegtree
#
# もし a==1 ならば :
#     pass
# そうでなくもし a<1 ならば :
#     表示する("a")
# そうでなければ:
#     表示する("a")
#
# if a==1：
#     pass
# elif a<1:
#     print("a")
# else:
#     print("a")
# Out:
# [#Source [#If cond: [#Infix left: [#Name 'a']name: [#Name '==']right: [#Int '1']]then: [#Block [#Pass 'pass']]elif: [# [#Elif cond: [#Infix left: [#Name 'a']name: [#Name '<']right: [#Int '1']]then: [#Block [#Expression [#ApplyExpr name: [#UName '表示する']params: [#Arguments [#QString '"a"']]]]]]]else: [#Else [#Block [#Expression [#ApplyExpr name: [#UName '表示する']params: [#Arguments [#QString '"a"']]]]]]][#If cond: [#Infix left: [#Name 'a']name: [#Name '==']right: [#Int '1']]then: [#Block [#Pass 'pass']]elif: [# [#Elif cond: [#Infix left: [#Name 'a']name: [#Name '<']right: [#Int '1']]then: [#Block [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString '"a"']]]]]]]else: [#Else [#Block [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString '"a"']]]]]]]]

# %%
# %%pegtree samoyed.pegtree
#
# for i in range(0,10,1):
#     print("a")
#
# i を 0 から 10 まで 1 ずつ増やしながら繰り返す:
#     表示する("a")
# Out:
# [#Source [#For each: [# [#Name 'i']]list: [#ApplyExpr name: [#Name 'range']params: [#Arguments [#Int '0'][#Int '10'][#Int '1']]]body: [#Block [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString '"a"']]]]]][#For each: [# [#Name 'i']]list: [#Int '0'][#Int '10'][#Int '1']body: [#Block [#Expression [#ApplyExpr name: [#UName '表示する']params: [#Arguments [#QString '"a"']]]]]]]

# %%
# %%pegtree samoyed.pegtree
# print("a")
# 表示する("a")
# Out:
# [#Source [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString '"a"']]]][#Expression [#ApplyExpr name: [#UName '表示する']params: [#Arguments [#QString '"a"']]]]]

# %%
# %%pegtree samoyed.pegtree
#
# while a<10:
#     print("a")
#
# a<10 の間繰り返す：
#     表示する("a")
# Out:
# [#Source [#While cond: [#Infix left: [#Name 'a']name: [#Name '<']right: [#Int '10']]body: [#Block [#Expression [#ApplyExpr name: [#Name 'print']params: [#Arguments [#QString '"a"']]]]]][#While cond: [#Infix left: [#Name 'a']name: [#Name '<']right: [#Int '10']]body: [#Block [#Expression [#ApplyExpr name: [#UName '表示する']params: [#Arguments [#QString '"a"']]]]]]]
